# %%
using Plots
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %%
plot(rand(100), marker = :square)
plot!(rand(100), marker = :circle)
# Out:
# only png or svg allowed. got: :html
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] _show(::Base.GenericIOBuffer{Array{UInt8,1}}, ::MIME{Symbol("text/html")}, ::Plots.Plot{Plots.PlotlyBackend}) at /home/mdpetter/.julia/packages/Plots/VPCjH/src/output.jl:176
#  [3] show(::Base.GenericIOBuffer{Array{UInt8,1}}, ::MIME{Symbol("text/html")}, ::Plots.Plot{Plots.PlotlyBackend}) at /home/mdpetter/.julia/packages/Plots/VPCjH/src/output.jl:198
#  [4] #sprint#340(::Nothing, ::Int64, ::Function, ::Function, ::MIME{Symbol("text/html")}, ::Vararg{Any,N} where N) at ./strings/io.jl:101
#  [5] sprint(::Function, ::MIME{Symbol("text/html")}, ::Vararg{Any,N} where N) at ./strings/io.jl:97
#  [6] _ijulia_display_dict(::Plots.Plot{Plots.PlotlyBackend}) at /home/mdpetter/.julia/packages/Plots/VPCjH/src/ijulia.jl:53
#  [7] display_dict(::Plots.Plot{Plots.PlotlyBackend}) at /home/mdpetter/.julia/packages/Plots/VPCjH/src/init.jl:42
#  [8] #invokelatest#1 at ./essentials.jl:742 [inlined]
# ...

# %%
p1 = plot(rand(100), marker = :square)
p2 = plot(rand(100), marker = :circle)
p3 = plot(rand(100), marker = :circle)
p10 = plot(p1,p2,layout = grid(2,1))
# Out:
# <div class='display:none'></div><unsafe-script style='display:none'>
# ...

# %%
#Plots.html_body(p1)
Plots.prepare_output(p10)

# %%
p1 = plot(rand(100), marker = :square)
p2 = plot(rand(100), marker = :circle)
p3 = plot(rand(100), marker = :circle)
p10 = plot(p1,p2,layout = grid(2,1));
#Plots.prepare_output(p10)
WebIO.render(p10)
# Out:
# (Scope("scope-3eb1d9ef-291c-45a4-b9d6-740b51a7a333", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[], Dict{Symbol,Any}(:id=>"plot-9069ebe9-f941-400c-9c68-04ec7590a687"), 0), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("_toImage"=>(Observable{Dict{Any,Any}} with 1 listeners. Value:
# Dict{Any,Any}(), nothing),"hover"=>(Observable{Dict{Any,Any}} with 0 listeners. Value:
# Dict{Any,Any}(), nothing),"selected"=>(Observable{Dict{Any,Any}} with 0 listeners. Value:
# Dict{Any,Any}(), nothing),"__gd_contents"=>(Observable{Any} with 0 listeners. Value:
# Dict{Any,Any}(), nothing),"click"=>(Observable{Dict{Any,Any}} with 0 listeners. Value:
# Dict{Any,Any}(), nothing),"image"=>(Observable{String} with 1 listeners. Value:
# "", nothing),"__get_gd_contents"=>(Observable{String} with 1 listeners. Value:
# "", nothing),"_downloadImage"=>(Observable{Dict{Any,Any}} with 1 listeners. Value:
# ...

# %%
plot(p10, fmt = :svg)
